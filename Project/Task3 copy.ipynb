// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

// 1. Класс Товар (Product) с улучшенной логикой и геттерами/сеттерами
public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    // Геттеры и сеттеры
    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set { price = value < 0 ? 0 : value; } // Защита от отрицательной цены
    }

    public int Quantity
    {
        get { return quantity; }
        set { quantity = value < 0 ? 0 : value; } // Защита от отрицательного количества
    }

    public string Category
    {
        get { return category; }
        set { category = value; }
    }

    public string Description
    {
        get { return description; }
        set { description = value; }
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity += amount;
        if (quantity < 0) quantity = 0; // Защита от отрицательного количества
        Console.WriteLine($"🔄 Количество товара '{name}' обновлено: {quantity} шт.");
    }

    public string GetProductInfo()
    {
        return $" Товар: {name} |  Цена: {price:C} |  Количество: {quantity} |  Категория: {category} |  Общая стоимость: {GetTotalPrice():C}";
    }
}

// 2. Класс Продавец (Seller) с улучшенной функциональностью
public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;
    private List<Product> products = new List<Product>();

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    // Геттеры и сеттеры
    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value < 0 ? 0 : value; }
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
        Console.WriteLine($" Товар '{product.Name}' добавлен продавцу {name}");
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product.Quantity >= quantity)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($" Продано {quantity} шт. товара '{product.Name}' продавцом {name}");
        }
        else
        {
            Console.WriteLine($" Недостаточно товара '{product.Name}' на складе. Доступно: {product.Quantity}, Запрошено: {quantity}");
        }
    }

    public string GetSellerInfo()
    {
        return $" Продавец: {name} |  ID: {employeeId} |  Зарплата: {salary:C} |  Контакты: {contactInfo} |  Товаров в управлении: {products.Count}";
    }

    public void ListSellerProducts()
    {
        Console.WriteLine($"\n Товары продавца {name}:");
        if (products.Count == 0)
        {
            Console.WriteLine("   Товаров нет");
            return;
        }
        
        foreach (var product in products)
        {
            Console.WriteLine($"   - {product.GetProductInfo()}");
        }
    }

    public List<Product> GetProducts()
    {
        return products;
    }
}

// 3. Класс Магазин (Store) с расширенной функциональностью
public class Store
{
    private string storeName;
    private string location;
    public string storeHours;
    private List<Seller> sellers = new List<Seller>();
    private List<Product> storeProducts = new List<Product>();

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    // Геттеры и сеттеры
    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
        Console.WriteLine($" Продавец {seller.Name} добавлен в магазин '{storeName}'");
    }

    public void AddProductToStore(Product product)
    {
        storeProducts.Add(product);
        Console.WriteLine($" Товар '{product.Name}' добавлен в магазин");
    }

    public void ListProducts()
    {
        Console.WriteLine($"\n ВСЕ ТОВАРЫ В МАГАЗИНЕ '{storeName}':");
        if (storeProducts.Count == 0 && sellers.Count == 0)
        {
            Console.WriteLine("   Товаров нет");
            return;
        }

        // Товары магазина
        if (storeProducts.Count > 0)
        {
            Console.WriteLine("\n Товары магазина:");
            foreach (var product in storeProducts)
            {
                Console.WriteLine($"   - {product.GetProductInfo()}");
            }
        }

        // Товары продавцов
        if (sellers.Count > 0)
        {
            Console.WriteLine("\n Товары продавцов:");
            foreach (var seller in sellers)
            {
                Console.WriteLine($"   Продавец: {seller.Name}");
                foreach (var product in seller.GetProducts())
                {
                    Console.WriteLine($"     - {product.GetProductInfo()}");
                }
            }
        }
    }

    public void ListSellers()
    {
        Console.WriteLine($"\n ПРОДАВЦЫ МАГАЗИНА '{storeName}':");
        if (sellers.Count == 0)
        {
            Console.WriteLine("   Продавцов нет");
            return;
        }
        
        foreach (var seller in sellers)
        {
            Console.WriteLine($"   - {seller.GetSellerInfo()}");
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName} |  Адрес: {location} |  Часы работы: {storeHours} |  Продавцов: {sellers.Count} |  Товаров: {storeProducts.Count}";
    }
}

// ДЕМОНСТРАЦИЯ РАБОТЫ КЛАССОВ
Console.WriteLine("===  ДЕМОНСТРАЦИЯ РАБОТЫ СИСТЕМЫ МАГАЗИНА ===\n");

// Создание экземпляров классов
Product product1 = new Product("Апельсины", 1.20m, 100, "Фрукты", "Сочные апельсины");
Product product2 = new Product("Яблоки", 0.80m, 150, "Фрукты", "Свежие яблоки");
Product product3 = new Product("Молоко", 1.50m, 50, "Молочные продукты", "Свежее молоко");

Seller seller1 = new Seller("Никита", "К1237", 3000.00m, "tresh78803@gmail.com");
Seller seller2 = new Seller("Анна", "К1238", 3200.00m, "anna@store.com");

Store store = new Store("Продукты", "Центр города", "Круглосуточно");

// Добавление продавцов в магазин
store.AddSeller(seller1);
store.AddSeller(seller2);

// Добавление товаров продавцам
seller1.AddProduct(product1);
seller1.AddProduct(product2);
seller2.AddProduct(product3);

// Добавление товаров непосредственно в магазин
store.AddProductToStore(new Product("Хлеб", 0.90m, 200, "Выпечка", "Свежий хлеб"));

// Вывод информации
Console.WriteLine("\n" + new string('=', 50));
Console.WriteLine(store.GetStoreInfo());
Console.WriteLine(new string('=', 50));

Console.WriteLine("\n" + new string('=', 50));
store.ListSellers();
Console.WriteLine(new string('=', 50));

Console.WriteLine("\n" + new string('=', 50));
store.ListProducts();
Console.WriteLine(new string('=', 50));

// Демонстрация продажи товаров
Console.WriteLine("\n" + new string('=', 50));
Console.WriteLine(" ДЕМОНСТРАЦИЯ ПРОДАЖ:");
Console.WriteLine(new string('=', 50));
seller1.SellProduct(product1, 10);
seller2.SellProduct(product3, 5);
seller1.SellProduct(product2, 200); // Попытка продать больше чем есть

// Вывод итоговой информации после продаж
Console.WriteLine("\n" + new string('=', 50));
Console.WriteLine("ИТОГОВАЯ ИНФОРМАЦИЯ ПОСЛЕ ПРОДАЖ:");
Console.WriteLine(new string('=', 50));
store.ListProducts();

// Демонстрация работы геттеров и сеттеров
Console.WriteLine("\n" + new string('=', 50));
Console.WriteLine("ДЕМОНСТРАЦИЯ ГЕТТЕРОВ И СЕТТЕРОВ:");
Console.WriteLine(new string('=', 50));
product1.Price = 1.50m; // Изменение цены через сеттер
product1.Quantity = 95; // Изменение количества через сеттер
Console.WriteLine($"Обновленная информация о товаре: {product1.GetProductInfo()}");
// Out:
// ===  ДЕМОНСТРАЦИЯ РАБОТЫ СИСТЕМЫ МАГАЗИНА ===
//
//  Продавец Никита добавлен в магазин 'Продукты'
//  Продавец Анна добавлен в магазин 'Продукты'
//  Товар 'Апельсины' добавлен продавцу Никита
//  Товар 'Яблоки' добавлен продавцу Никита
//  Товар 'Молоко' добавлен продавцу Анна
//  Товар 'Хлеб' добавлен в магазин
//
// ...
// Магазин: Продукты |  Адрес: Центр города |  Часы работы: Круглосуточно |  Продавцов: 2 |  Товаров: 1
// ...
//
// ...
//
//  ПРОДАВЦЫ МАГАЗИНА 'Продукты':
//    -  Продавец: Никита |  ID: К1237 |  Зарплата: ¤3,000.00 |  Контакты: tresh78803@gmail.com |  Товаров в управлении: 2
//    -  Продавец: Анна |  ID: К1238 |  Зарплата: ¤3,200.00 |  Контакты: anna@store.com |  Товаров в управлении: 1
// ...
//
// ...
//
//  ВСЕ ТОВАРЫ В МАГАЗИНЕ 'Продукты':
//
//  Товары магазина:
//    -  Товар: Хлеб |  Цена: ¤0.90 |  Количество: 200 |  Категория: Выпечка |  Общая стоимость: ¤180.00
//
//  Товары продавцов:
//    Продавец: Никита
// ...
